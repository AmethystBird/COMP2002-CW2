# %%
import random

class Module:
    #Object variables
    moduleCode = ""
    lecturerName = ""
    moduleConflicts = []
    
    #Sessions attached
    lectures = 1
    labs = -1
    
    #Constructor
    def __init__(self, moduleCode, lecturerName, conflictingModules, labs):
        self.moduleCode = moduleCode
        self.lecturerName = lecturerName
        self.moduleConflicts = conflictingModules
        self.labs = labs
    
    #Session assignment through value decrementation
    #def AssignLecture():
    #    if (lectures > 0):
    #        lectures = lectures - 1
    #    else:
    #        print("Error: Attempted assignment of lecture when there are no lectures to assign.")
    
    def AssignLab():
        if (labs > 0):
            labs = labs - 1
        else:
            print("Error: Attempted assignment of lab when there are no labs to assign.")
    
    #Regular getters & setters
    def GetModuleCode():
        return self.moduleCode
    
    def SetModuleCode(name):
        this.moduleCode = moduleCode
    
    def GetLecturerName():
        return self.lecturerName
    
    def SetLecturerName(lecturerName):
        this.lecturerName = lecturerName
    
    def GetConflictingModules():
        return self.conflictingModules
    
    def SetConflictingModules(conflictingModules):
        this.conflictingModules = conflictingModules
    
    def GetLectures():
        return self.lectures
    
    def SetLectures(lectures):
        this.lectures = lectures
    
    def GetLabs():
        return self.lectures
    
    def SetLabs(labs):
        this.labs = labs

#A 3 day session within a day
class Session:
    lecture = "Empty"
    lab1 = "Empty"
    lab2 = "Empty"
    slots = [lecture, lab1, lab2]

#A day containing given sessions
class Day:
    Session1 = Session()
    Session2 = Session()
    Session3 = Session()
    Session4 = Session()
    sessions = [Session1, Session2, Session3, Session4]

#A timetable containing given days
class Timetable:
    Monday = Day()
    Tuesday = Day()
    Wednesday = Day()
    Thursday = Day()
    Friday = Day()
    days = [Monday, Tuesday, Wednesday, Thursday, Friday]

modules = open("Modules.txt")
#print(modules.read())

allModules = {}
dictionaryIndex = 0

lectures = 1
for moduleAttributes in modules:
    moduleAttributesFormatted = moduleAttributes.split('|')
    #print(x, "<< INDEX SPLIT >>")
    moduleCode = moduleAttributesFormatted[0]
    lecturerName = moduleAttributesFormatted[1]
    sessionsUnformatted = moduleAttributesFormatted[2]
    labs = int(sessionsUnformatted)
    #labs = int(sessions) - 1 #First session is lecture, so -1
    
    #print(moduleCode, lecturerName, sessions, lectures, labs)
    
    conflictingModules = moduleAttributesFormatted[3]
    conflictingModulesFormatted = conflictingModules.split(',')
    #for conflictingModule in conflictingModulesFormatted:
        #print(conflictingModule)
    
    allModules[dictionaryIndex] = Module(moduleCode, lecturerName, conflictingModules, labs)
    dictionaryIndex = dictionaryIndex + 1

#Create random timetable
randomTimetable = [[["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"]],
                   [["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"]],
                   [["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"]],
                   [["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"]],
                   [["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"], ["Lecture", "Lab1", "Lab2"]]]

modulesIndex = 0 #Cannot go above 16 (17 modules, & lectures by implication)
EmptyModule1 = Module("", "", [], "")
EmptyModule2 = Module("", "", [], "")
EmptyModule3 = Module("", "", [], "")
EmptyModule4 = Module("", "", [], "")
modulesPerDay = {0: EmptyModule1, 1: EmptyModule2, 2: EmptyModule3, 3: EmptyModule4}

if any(allModules.values()):
    print("TRUE")
else:
    print("FALSE")

#x = allModules.get(0)
#print(x)

for day in randomTimetable:
    #print("DAY: ", day)
    for module in modulesPerDay:
        if modulesIndex < 17:
            modulesPerDay[module] = allModules.get(modulesIndex)
            print(modulesPerDay[module].moduleCode)
            modulesIndex = modulesIndex + 1
    for session in day:
        #print("SESSION: ", session)
        for module in modulesPerDay:
            moduleCode = module.moduleCode
            print(moduleCode)
        #for slot in session:
            #print("SLOT: ", slot)

#randomTimetable = Timetable()
#randomModuleIndex = random.randint(0, 16)
#module = allModules[randomModuleIndex]

#randomTimetable[0] = [1, 2, 3]
#randomTimetable[1] = [4, 5, 6]
#print(randomTimetable)

#for day in randomTimetable.days:
#    for session in day.sessions:
#        for slot in session.slots:
# Out:
# TRUE
# MOD001
# MOD002
# MOD003
# MOD004
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 136>()
#     143 for session in day:
#     144     #print("SESSION: ", session)
#     145     for module in modulesPerDay:
# --> 146         moduleCode = module.moduleCode
#     147         print(moduleCode)
#
# AttributeError: 'int' object has no attribute 'moduleCode'
